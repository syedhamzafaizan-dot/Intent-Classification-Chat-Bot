# %% [markdown]
# # Intent Classification Chatbot using Neural Network
#
# ## 1. Installing the Necessary Packages

# %%
# !pip install nltk colorama numpy scikit-learn Flask -q

# %%
# All packages are already installed and compatible with Python 3.14!
import sys
print(f"Python version: {sys.version}")
print("✓ All required packages are compatible with Python 3.14.2")
# Out:
# Python version: 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]
# ✓ All required packages are compatible with Python 3.14.2

# %% [markdown]
# ## 2. Defining the Intentions of the Chatbot

# %%
import json

intents_data = {
    "intents": [
        {
            "tag": "greeting",
            "patterns": ["Hi", "Hey", "Is anyone there?", "Hello", "Hay"],
            "responses": ["Hello", "Hi", "Hi there"]
        },
        {
            "tag": "goodbye",
            "patterns": ["Bye", "See you later", "Goodbye"],
            "responses": ["See you later", "Have a nice day", "Bye! Come back again"]
        },
        {
            "tag": "thanks",
            "patterns": ["Thanks", "Thank you", "That's helpful", "Thanks for the help"],
            "responses": ["Happy to help!", "Any time!", "My pleasure", "You're most welcome!"]
        },
        {
            "tag": "about",
            "patterns": ["Who are you?", "What are you?", "Who you are?"],
            "responses": ["I.m Joana, your bot assistant", "I'm Joana, an Artificial Intelligent bot"]
        },
        {
            "tag": "name",
            "patterns": ["what is your name", "what should I call you", "whats your name?"],
            "responses": ["You can call me Joana.", "I'm Joana!", "Just call me as Joana"]
        },
        {
            "tag": "help",
            "patterns": [
                "Could you help me?", "give me a hand please", "Can you help?",
                "What can you do for me?", "I need a support", "I need a help", "support me please"
            ],
            "responses": [
                "Tell me how can assist you",
                "Tell me your problem to assist you",
                "Yes Sure, How can I support you"
            ]
        },
        {
            "tag": "createaccount",
            "patterns": [
                "I need to create a new account", "how to open a new account",
                "I want to create an account", "can you create an account for me",
                "how to open a new account"
            ],
            "responses": [
                "You can just easily create a new account from our web site",
                "Just go to our web site and follow the guidelines to create a new account"
            ]
        },
        {
            "tag": "complaint",
            "patterns": [
                "have a complaint", "I want to raise a complaint",
                "there is a complaint about a service"
            ],
            "responses": [
                "Please provide us your complaint in order to assist you",
                "Please mention your complaint, we will reach you and sorry for any inconvenience caused"
            ]
        }
    ]
}

with open("intents.json", "w") as f:
    json.dump(intents_data, f, indent=4)

print("Intents file created successfully!")
# Out:
# Intents file created successfully!

# %%
# Load and display intents
with open("intents.json") as f:
    intents = json.load(f)

for intent in intents["intents"]:
    print(intent["tag"], "→", intent["patterns"][:2])
# Out:
# greeting → ['Hi', 'Hey']
# goodbye → ['Bye', 'See you later']
# thanks → ['Thanks', 'Thank you']
# about → ['Who are you?', 'What are you?']
# name → ['what is your name', 'what should I call you']
# help → ['Could you help me?', 'give me a hand please']
# createaccount → ['I need to create a new account', 'how to open a new account']
# complaint → ['have a complaint', 'I want to raise a complaint']

# %% [markdown]
# ## 3. Importing the Required Packages

# %%
import json
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder

print("✓ Using scikit-learn MLPClassifier (compatible with Python 3.14)")
# Out:
# ✓ Using scikit-learn MLPClassifier (compatible with Python 3.14)

# %% [markdown]
# ## 4. Reading the Json file and Processing

# %%
with open("intents.json") as file:
    data = json.load(file)

training_sentences = []
training_labels = []
labels = []
responses = []

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        training_sentences.append(pattern)
        training_labels.append(intent["tag"])
    responses.append(intent["responses"])

    if intent["tag"] not in labels:
        labels.append(intent["tag"])

print("Number of training sentences:", len(training_sentences))
print("Unique labels:", labels)
print("Training labels:", training_labels[:10])
# Out:
# Number of training sentences: 33
# Unique labels: ['greeting', 'goodbye', 'thanks', 'about', 'name', 'help', 'createaccount', 'complaint']
# Training labels: ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'goodbye', 'goodbye', 'goodbye', 'thanks', 'thanks']

# %% [markdown]
# ## 5. Label Encoding Chatbot Intents

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

print("Encoded labels:", training_labels[:10])
print("Classes:", lbl_encoder.classes_)
# Out:
# Encoded labels: [4 4 4 4 4 3 3 3 7 7]
# Classes: ['about' 'complaint' 'createaccount' 'goodbye' 'greeting' 'help' 'name'
#  'thanks']

# %% [markdown]
# ## 6. Text Vectorization

# %%
# Using TfidfVectorizer instead of tokenization
vectorizer = TfidfVectorizer(max_features=1000, ngram_range=(1, 2))
X_train = vectorizer.fit_transform(training_sentences)

print("Vectorized shape:", X_train.shape)
print("Feature names (first 10):", vectorizer.get_feature_names_out()[:10])
# Out:
# Vectorized shape: (33, 104)
# Feature names (first 10): ['about' 'about service' 'account' 'account for' 'an' 'an account'
#  'anyone' 'anyone there' 'are' 'are you']

# %% [markdown]
# ## 7. Training a Neural Network

# %%
# Create a Multi-layer Perceptron Neural Network
model = MLPClassifier(
    hidden_layer_sizes=(16, 16),  # Two hidden layers with 16 neurons each
    activation='relu',
    max_iter=200,
    random_state=42,
    verbose=True
)

print("✓ Neural Network Model created with scikit-learn")
# Out:
# ✓ Neural Network Model created with scikit-learn

# %%
# Train the neural network
model.fit(X_train, training_labels)

# Calculate accuracy
accuracy = model.score(X_train, training_labels)
print(f"\nFinal training accuracy: {accuracy * 100:.2f}%")
# Out:
# Iteration 1, loss = 2.07847621
# Iteration 2, loss = 2.07438124
# Iteration 3, loss = 2.07030093
# Iteration 4, loss = 2.06624654
# Iteration 5, loss = 2.06224701
# Iteration 6, loss = 2.05827724
# Iteration 7, loss = 2.05432512
# Iteration 8, loss = 2.05039275
# Iteration 9, loss = 2.04659261
# Iteration 10, loss = 2.04286048
# Iteration 11, loss = 2.03914609
# Iteration 12, loss = 2.03554943
# Iteration 13, loss = 2.03193192
# Iteration 14, loss = 2.02830734
# Iteration 15, loss = 2.02472127
# Iteration 16, loss = 2.02117202
# Iteration 17, loss = 2.01767644
# Iteration 18, loss = 2.01421646
# Iteration 19, loss = 2.01081373
# Iteration 20, loss = 2.00742413
# Iteration 21, loss = 2.00403892
# Iteration 22, loss = 2.00062482
# Iteration 23, loss = 1.99716861
# Iteration 24, loss = 1.99369560
# Iteration 25, loss = 1.99022114
# Iteration 26, loss = 1.98670774
# Iteration 27, loss = 1.98314104
# Iteration 28, loss = 1.97960873
# Iteration 29, loss = 1.97606969
# Iteration 30, loss = 1.97248634
# Iteration 31, loss = 1.96885898
# Iteration 32, loss = 1.96521450
# Iteration 33, loss = 1.96157197
# Iteration 34, loss = 1.95790059
# Iteration 35, loss = 1.95421339
# Iteration 36, loss = 1.95048646
# Iteration 37, loss = 1.94667525
# Iteration 38, loss = 1.94287081
# Iteration 39, loss = 1.93898622
# Iteration 40, loss = 1.93504142
# Iteration 41, loss = 1.93105530
# Iteration 42, loss = 1.92701409
# Iteration 43, loss = 1.92291542
# Iteration 44, loss = 1.91875572
# Iteration 45, loss = 1.91451117
# Iteration 46, loss = 1.91019980
# Iteration 47, loss = 1.90576942
# Iteration 48, loss = 1.90123579
# Iteration 49, loss = 1.89664223
# Iteration 50, loss = 1.89203869
# Iteration 51, loss = 1.88734827
# Iteration 52, loss = 1.88256381
# Iteration 53, loss = 1.87773609
# Iteration 54, loss = 1.87282280
# Iteration 55, loss = 1.86787809
# Iteration 56, loss = 1.86290212
# Iteration 57, loss = 1.85785152
# Iteration 58, loss = 1.85272038
# Iteration 59, loss = 1.84749519
# Iteration 60, loss = 1.84218551
# Iteration 61, loss = 1.83682246
# Iteration 62, loss = 1.83138312
# Iteration 63, loss = 1.82585583
# Iteration 64, loss = 1.82023092
# Iteration 65, loss = 1.81448615
# Iteration 66, loss = 1.80866603
# Iteration 67, loss = 1.80278814
# Iteration 68, loss = 1.79685696
# Iteration 69, loss = 1.79084179
# Iteration 70, loss = 1.78470817
# Iteration 71, loss = 1.77847513
# Iteration 72, loss = 1.77221041
# Iteration 73, loss = 1.76586826
# Iteration 74, loss = 1.75945386
# Iteration 75, loss = 1.75293375
# Iteration 76, loss = 1.74639731
# Iteration 77, loss = 1.73979334
# Iteration 78, loss = 1.73307909
# Iteration 79, loss = 1.72630743
# Iteration 80, loss = 1.71953352
# Iteration 81, loss = 1.71268032
# Iteration 82, loss = 1.70576806
# Iteration 83, loss = 1.69880642
# Iteration 84, loss = 1.69176424
# Iteration 85, loss = 1.68466717
# Iteration 86, loss = 1.67757300
# Iteration 87, loss = 1.67041916
# Iteration 88, loss = 1.66325111
# Iteration 89, loss = 1.65600126
# Iteration 90, loss = 1.64857210
# Iteration 91, loss = 1.64101060
# Iteration 92, loss = 1.63339369
# Iteration 93, loss = 1.62553659
# Iteration 94, loss = 1.61747071
# Iteration 95, loss = 1.60934720
# Iteration 96, loss = 1.60125528
# Iteration 97, loss = 1.59297112
# Iteration 98, loss = 1.58458503
# Iteration 99, loss = 1.57611668
# Iteration 100, loss = 1.56736864
# Iteration 101, loss = 1.55851285
# Iteration 102, loss = 1.54949182
# Iteration 103, loss = 1.54020266
# Iteration 104, loss = 1.53076636
# Iteration 105, loss = 1.52120784
# Iteration 106, loss = 1.51154188
# Iteration 107, loss = 1.50185546
# Iteration 108, loss = 1.49202152
# Iteration 109, loss = 1.48197405
# Iteration 110, loss = 1.47171134
# Iteration 111, loss = 1.46134874
# Iteration 112, loss = 1.45099810
# Iteration 113, loss = 1.44061031
# Iteration 114, loss = 1.43016760
# Iteration 115, loss = 1.41966607
# Iteration 116, loss = 1.40903398
# Iteration 117, loss = 1.39833485
# Iteration 118, loss = 1.38756701
# Iteration 119, loss = 1.37667888
# Iteration 120, loss = 1.36581712
# Iteration 121, loss = 1.35487418
# Iteration 122, loss = 1.34390500
# Iteration 123, loss = 1.33290639
# Iteration 124, loss = 1.32185813
# Iteration 125, loss = 1.31077227
# Iteration 126, loss = 1.29967969
# Iteration 127, loss = 1.28855520
# Iteration 128, loss = 1.27743645
# Iteration 129, loss = 1.26636525
# Iteration 130, loss = 1.25537111
# Iteration 131, loss = 1.24455382
# Iteration 132, loss = 1.23380418
# Iteration 133, loss = 1.22307166
# Iteration 134, loss = 1.21232041
# Iteration 135, loss = 1.20170518
# Iteration 136, loss = 1.19121783
# Iteration 137, loss = 1.18071698
# Iteration 138, loss = 1.17025063
# Iteration 139, loss = 1.15980470
# Iteration 140, loss = 1.14936367
# Iteration 141, loss = 1.13886148
# Iteration 142, loss = 1.12839980
# Iteration 143, loss = 1.11798154
# Iteration 144, loss = 1.10755711
# Iteration 145, loss = 1.09712286
# Iteration 146, loss = 1.08671815
# Iteration 147, loss = 1.07639852
# Iteration 148, loss = 1.06618126
# Iteration 149, loss = 1.05600334
# Iteration 150, loss = 1.04589433
# Iteration 151, loss = 1.03580140
# Iteration 152, loss = 1.02577466
# Iteration 153, loss = 1.01585428
# Iteration 154, loss = 1.00597548
# Iteration 155, loss = 0.99611883
# Iteration 156, loss = 0.98634919
# Iteration 157, loss = 0.97658127
# Iteration 158, loss = 0.96682499
# Iteration 159, loss = 0.95710477
# Iteration 160, loss = 0.94741350
# Iteration 161, loss = 0.93774984
# Iteration 162, loss = 0.92816822
# Iteration 163, loss = 0.91866024
# Iteration 164, loss = 0.90918925
# Iteration 165, loss = 0.89983762
# Iteration 166, loss = 0.89056939
# Iteration 167, loss = 0.88140037
# Iteration 168, loss = 0.87227508
# Iteration 169, loss = 0.86319269
# Iteration 170, loss = 0.85416050
# Iteration 171, loss = 0.84517937
# Iteration 172, loss = 0.83627159
# Iteration 173, loss = 0.82742799
# Iteration 174, loss = 0.81863483
# Iteration 175, loss = 0.80992188
# Iteration 176, loss = 0.80128376
# Iteration 177, loss = 0.79270699
# Iteration 178, loss = 0.78421673
# Iteration 179, loss = 0.77579421
# Iteration 180, loss = 0.76741321
# Iteration 181, loss = 0.75912934
# Iteration 182, loss = 0.75091866
# Iteration 183, loss = 0.74280258
# Iteration 184, loss = 0.73472745
# Iteration 185, loss = 0.72671327
# Iteration 186, loss = 0.71878575
# Iteration 187, loss = 0.71094349
# Iteration 188, loss = 0.70311887
# Iteration 189, loss = 0.69536230
# Iteration 190, loss = 0.68769040
# Iteration 191, loss = 0.68008076
# Iteration 192, loss = 0.67250814
# Iteration 193, loss = 0.66502197
# Iteration 194, loss = 0.65760343
# Iteration 195, loss = 0.65024310
# Iteration 196, loss = 0.64297260
# Iteration 197, loss = 0.63575857
# Iteration 198, loss = 0.62859100
# Iteration 199, loss = 0.62150108
# Iteration 200, loss = 0.61448181
# C:\Users\faiza\AppData\Roaming\Python\Python314\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Final training accuracy: 90.91%

# %% [markdown]
# ## 8. Saving the Model for Future Use

# %%
import pickle

# Save the trained model
with open("chat_model.pkl", "wb") as f:
    pickle.dump(model, f)

# Save the vectorizer
with open("vectorizer.pickle", "wb") as handle:
    pickle.dump(vectorizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Save the fitted label encoder
with open("label_encoder.pickle", "wb") as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)

print("Model and encoders saved successfully!")
# Out:
# Model and encoders saved successfully!

# %% [markdown]
# ## 9. Interactive Chat Function

# %%
# Test the chatbot with sample queries (without interactive loop)
import colorama
colorama.init()
from colorama import Fore, Style
import random
import pickle
import json

# Load intents data
with open("intents.json") as file:
    data = json.load(file)

# Load trained model
with open("chat_model.pkl", "rb") as f:
    model = pickle.load(f)

# Load vectorizer
with open("vectorizer.pickle", "rb") as handle:
    vectorizer = pickle.load(handle)

# Load label encoder
with open("label_encoder.pickle", "rb") as enc:
    lbl_encoder = pickle.load(enc)

# Test with sample messages
test_messages = [
    "Hello",
    "Who are you?",
    "Can you help me?",
    "I want to create an account",
    "Thanks for your help",
    "Goodbye"
]

print(Fore.YELLOW + "🤖 Chatbot Demo - Testing with sample messages:\n" + Style.RESET_ALL)

for msg in test_messages:
    print(Fore.LIGHTBLUE_EX + f"User: {msg}" + Style.RESET_ALL)
    
    # Vectorize and predict
    inp_vectorized = vectorizer.transform([msg])
    prediction = model.predict(inp_vectorized)
    tag = lbl_encoder.inverse_transform(prediction)[0]
    
    # Find and display response
    for intent in data["intents"]:
        if intent["tag"] == tag:
            response = random.choice(intent["responses"])
            print(Fore.GREEN + f"ChatBot: {response}" + Style.RESET_ALL)
            break
    print()
# Out:
# 🤖 Chatbot Demo - Testing with sample messages:
# User: Hello
# ChatBot: Hello
#
# User: Who are you?
# ChatBot: See you later
#
# User: Can you help me?
# ChatBot: Tell me how can assist you
#
# User: I want to create an account
# ChatBot: You can just easily create a new account from our web site
#
# User: Thanks for your help
# ChatBot: You're most welcome!
#
# User: Goodbye
# ChatBot: Bye! Come back again

# %% [markdown]
# ## 10. Interactive Chat (Optional)
# Run this cell if you want to chat interactively. Type your messages and press Enter. Type 'quit' to stop.

# %%
# Interactive Chat - Edit the messages list below to test different inputs!

# 👇 Add your own messages here:
my_messages = [
    "Hi there",
    "What's your name?",
    "Can you help me?",
    # Add more messages here...
]

print(Fore.YELLOW + "💬 Testing your custom messages:\n" + Style.RESET_ALL)

for user_msg in my_messages:
    print(Fore.LIGHTBLUE_EX + f"User: {user_msg}" + Style.RESET_ALL)
    
    # Vectorize and predict
    inp_vectorized = vectorizer.transform([user_msg])
    prediction = model.predict(inp_vectorized)
    tag = lbl_encoder.inverse_transform(prediction)[0]
    
    # Find and display response

    
    for intent in data["intents"]:
        if intent["tag"] == tag:
            response = random.choice(intent["responses"])
            print(Fore.GREEN + f"ChatBot: {response}" + Style.RESET_ALL)
            break
    print()

print(Fore.CYAN + "💡 Tip: Edit the 'my_messages' list above to test different inputs!" + Style.RESET_ALL)
# Out:
# 💬 Testing your custom messages:
#
# User: Hi there
# ChatBot: Hi
#
# User: What's your name?
# ChatBot: You can call me Joana.
#
# User: Can you help me?
# ChatBot: Yes Sure, How can I support you
#
# 💡 Tip: Edit the 'my_messages' list above to test different inputs!
